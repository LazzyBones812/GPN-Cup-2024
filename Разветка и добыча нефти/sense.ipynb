# %% [markdown]
# **Назначение расщелина**
#
# Есть NAN и есть нужные артефакты. Вопрос: удалять ли NaN
#
# Статус поиска - что такое NaN
#
# Изучить как влияет компании и как влияет тип инструменты на добычу
#
# Полученные пропуски - обработать, выявить выбросы и шумы
#
# Для отбора признаков
#  - Построить корреляционную матрицу heatmap
#  - Использовать статистические метрики
#
# Сформировать тренировочный и тестовый датасет
#
# Построить гистограмму по количеству всяких простоев итд
#
# Некоторые фичи, которые линейно зависят друг от друга
#
# Очень много нулей
#
# Проблема - статус в процессе, но даты окончания есть
#
# Lass0, corr, RF - отбор фич
