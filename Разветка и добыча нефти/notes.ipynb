# %% [markdown]
# 1. Данные по времени могут несовпадать - могут быть шумы
# 2. Данные по времени могут происходить в прошлом (дата окончания раньше чем дата начала) - могут быть шумы
# 3. Учитывать данные об артефактах на различных землях - можно исключить этот признак, если на это есть причины
# 4. Дисбаланс классов артефактов - получить сроки предсказания артефактов
# 5. Можно применять нейронные сети
# 6. Некоторые параметры можно объединить, например
#      - Количество: труб, отвилков, аварий, брака, осложнений, простоев, ремонтов
#      - Глубина отвилков
#      - Общее время: поиска, активного поиска, простоев
#      - Путь поиска: общий и в первом отвилке
# 7. Нужно ли удалять данные, если работы еще не завершены? Разбиение на тестовую и тренировочную выборку
# 8. Предсказывать время вплоть до дней, часов
# 9. Построить универсальную модель
# 10. Количество кратно 0.9
# 11. Столбец "Цель" - исследовать данные - это различные категории поиска
# 12. В одной расщелине несколько отвилков
# 13. Одна расщелина может относится к разным королевствам - под одним номером разные расщелины
# 14. Разные категории для расщелин
# 15. Глубина больше длины - возможно выброс
#
# 16. Нужно предсказать срок поиска в расщелине - расщелина уникальна - проверить на дубликаты
# 17. Земля может разрабатываться несколькими королевствами
# 18. Смена организаций
